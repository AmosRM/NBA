# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/amos/Downloads/all_playoff_games.csv')

# %%
df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])

# %%
df
# Out:
#       Unnamed: 0  SEASON_ID   TEAM_ID_A TEAM_ABBREVIATION_A  \
# 0              2      42021  1610612744                 GSW
# 1              6      42021  1610612738                 BOS
# 2              9      42021  1610612738                 BOS
# 3             13      42021  1610612744                 GSW
# 4             17      42021  1610612744                 GSW
# ...          ...        ...         ...                 ...
# 3034       12137      41983  1610612742                 DAL
# 3035       12142      41983  1610612765                 DET
# 3036       12146      41983  1610612762                 UTH
# 3037       12149      41983  1610612738                 BOS
# 3038       12154      41983  1610612749                 MIL
#
#                 TEAM_NAME_A   GAME_ID  GAME_DATE    MATCHUP_A WL_A  MIN_A  \
# 0     Golden State Warriors  42100405 2022-06-13  GSW vs. BOS    W    240
# 1            Boston Celtics  42100404 2022-06-10  BOS vs. GSW    L    241
# ...

# %% [markdown]
# #   CREATE COLUMN TO SHOW WHICH GAME IT IS IN THE SERIES (1-7)
# #   ANOTHER COLUMN FOR SERIES RESULT
# #   -- COLUMN FINALS (YES/NO) --
